# %%
Verse = input("Welcome to the Bible searcher type in a verse in the book of Philemon: ")
    if Verse > 25:
        input("Thats not a Verse in Philemon! Philemon only contains 25 re-enter a verse")
    if Verse == 1:
        print("Paul, a prisoner for Christ Jesus, and Timothy our brother,To Philemon our beloved fellow worker. If you want to enter another Verse input another number, but if your done type done.")
    if Verse == 2:
        print("and Apphia our sister and Archippus our fellow soldier, and the church in your house")
